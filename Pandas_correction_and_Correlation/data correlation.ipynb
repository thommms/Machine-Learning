# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#importing the housing data and removed the last 18 rows of the dataset and saving to a new csv file

df =pd.read_csv('Group6_Task_1_Output.csv') #.to_csv(r'housing-data.csv', index = False)

# %%
#reading the new csv file into a dataframe
#df = pd.read_csv('housing-data.csv')#

# %%
df.head(6)
# Out:
#    Unnamed: 0      Price  Distance  Zipcode  #Bedroom  #Bathroom  \
# 0           0   950000.0      11.0   3018.0       3.0        1.0
# 1           1   931000.0      11.1   3025.0       3.0        2.0
# 2           2   565000.0       5.9   3032.0       2.0        2.0
# 3           3  2215000.0      11.0   3147.0       4.0        2.0
# 4           4  1650000.0      11.0   3147.0       3.0        1.0
# 5           5  2170000.0       9.2   3104.0       4.0        2.0
#
#    #-Car Garage  Lot_size  Property_count  Suburb_indexed  Type_indexed  \
# 0           1.0     399.0          5301.0            52.0           0.0
# 1           1.0     590.0          5132.0            69.0           0.0
# 2           1.0     103.0          6567.0            24.0           2.0
# 3           1.0     681.0          3052.0            62.0           0.0
# 4           1.0     697.0          3052.0            62.0           0.0
# 5           2.0    1040.0          7809.0             7.0           0.0
#
#    Region_name_indexed
# 0                  2.0
# 1                  2.0
# 2                  2.0
# 3                  0.0
# 4                  0.0
# 5                  0.0

# %%
#calculate the correlation using the pearson method
df_pearson = df.corr(method="pearson")
df_pearson
# Out:
#                      Unnamed: 0     Price  Distance   Zipcode  #Bedroom  \
# Unnamed: 0             1.000000  0.011719  0.001665 -0.004636  0.000309
# Price                  0.011719  1.000000 -0.262172  0.113908  0.403429
# Distance               0.001665 -0.262172  1.000000  0.468404  0.218014
# Zipcode               -0.004636  0.113908  0.468404  1.000000  0.083134
# #Bedroom               0.000309  0.403429  0.218014  0.083134  1.000000
# #Bathroom              0.013819  0.435309  0.091294  0.126997  0.575643
# #-Car Garage          -0.008986  0.180552  0.225430  0.055005  0.356536
# Lot_size               0.009883  0.023218  0.010864  0.026745  0.003048
# Property_count        -0.000163 -0.024929 -0.022572  0.057510 -0.056086
# Suburb_indexed        -0.007308 -0.161425  0.526229  0.292054  0.103779
# Type_indexed          -0.002606 -0.241443 -0.076319  0.001549 -0.272168
# Region_name_indexed   -0.007411 -0.311913  0.513356  0.002587  0.103163
#
#                      #Bathroom  #-Car Garage  Lot_size  Property_count  \
# Unnamed: 0            0.013819     -0.008986  0.009883       -0.000163
# Price                 0.435309      0.180552  0.023218       -0.024929
# Distance              0.091294      0.225430  0.010864       -0.022572
# Zipcode               0.126997      0.055005  0.026745        0.057510
# #Bedroom              0.575643      0.356536  0.003048       -0.056086
# #Bathroom             1.000000      0.286426  0.028602       -0.042762
# #-Car Garage          0.286426      1.000000  0.015707       -0.004984
# Lot_size              0.028602      0.015707  1.000000       -0.002754
# Property_count       -0.042762     -0.004984 -0.002754        1.000000
# Suburb_indexed        0.057173      0.052256  0.027829       -0.441994
# Type_indexed         -0.010914     -0.129003 -0.003639        0.008417
# Region_name_indexed  -0.016329      0.075905  0.011539       -0.176467
#
#                      Suburb_indexed  Type_indexed  Region_name_indexed
# Unnamed: 0                -0.007308     -0.002606            -0.007411
# Price                     -0.161425     -0.241443            -0.311913
# Distance                   0.526229     -0.076319             0.513356
# Zipcode                    0.292054      0.001549             0.002587
# #Bedroom                   0.103779     -0.272168             0.103163
# #Bathroom                  0.057173     -0.010914            -0.016329
# #-Car Garage               0.052256     -0.129003             0.075905
# Lot_size                   0.027829     -0.003639             0.011539
# Property_count            -0.441994      0.008417            -0.176467
# Suburb_indexed             1.000000     -0.061857             0.440480
# Type_indexed              -0.061857      1.000000            -0.094738
# Region_name_indexed        0.440480     -0.094738             1.000000

# %%
#Lets plot a graph and see how this looks like on graph

sb.heatmap(df_pearson, 
            xticklabels=df_pearson.columns,
            yticklabels=df_pearson.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.001)
# Out:
# <AxesSubplot:>

# %%
#calculate the correlation using the spearman method
df_spearman = df.corr(method="spearman")
df_spearman
# Out:
#                      Unnamed: 0     Price  Distance   Zipcode  #Bedroom  \
# Unnamed: 0             1.000000  0.016994 -0.000132  0.000844  0.002642
# Price                  0.016994  1.000000 -0.303331  0.290693  0.415919
# Distance              -0.000132 -0.303331  1.000000  0.255564  0.263664
# Zipcode                0.000844  0.290693  0.255564  1.000000  0.081256
# #Bedroom               0.002642  0.415919  0.263664  0.081256  1.000000
# #Bathroom              0.014075  0.377854  0.117142  0.154097  0.573251
# #-Car Garage          -0.008733  0.195914  0.293631  0.070419  0.417572
# Lot_size              -0.002267  0.153381  0.314920  0.131346  0.331713
# Property_count         0.005068  0.032981 -0.105569  0.128873 -0.037649
# Suburb_indexed        -0.005012 -0.157416  0.357520  0.124607  0.088702
# Type_indexed          -0.007191 -0.356370 -0.071683  0.049120 -0.354886
# Region_name_indexed   -0.008737 -0.327458  0.333471 -0.392307  0.094608
#
#                      #Bathroom  #-Car Garage  Lot_size  Property_count  \
# Unnamed: 0            0.014075     -0.008733 -0.002267        0.005068
# Price                 0.377854      0.195914  0.153381        0.032981
# Distance              0.117142      0.293631  0.314920       -0.105569
# Zipcode               0.154097      0.070419  0.131346        0.128873
# #Bedroom              0.573251      0.417572  0.331713       -0.037649
# #Bathroom             1.000000      0.329754  0.134341       -0.018122
# #-Car Garage          0.329754      1.000000  0.346199       -0.019308
# Lot_size              0.134341      0.346199  1.000000       -0.024030
# Property_count       -0.018122     -0.019308 -0.024030        1.000000
# Suburb_indexed        0.072993      0.037082  0.118123       -0.607194
# Type_indexed         -0.051763     -0.180848 -0.262308        0.024695
# Region_name_indexed  -0.028957      0.063155  0.083020       -0.219788
#
#                      Suburb_indexed  Type_indexed  Region_name_indexed
# Unnamed: 0                -0.005012     -0.007191            -0.008737
# Price                     -0.157416     -0.356370            -0.327458
# Distance                   0.357520     -0.071683             0.333471
# Zipcode                    0.124607      0.049120            -0.392307
# #Bedroom                   0.088702     -0.354886             0.094608
# #Bathroom                  0.072993     -0.051763            -0.028957
# #-Car Garage               0.037082     -0.180848             0.063155
# Lot_size                   0.118123     -0.262308             0.083020
# Property_count            -0.607194      0.024695            -0.219788
# Suburb_indexed             1.000000     -0.046717             0.344365
# Type_indexed              -0.046717      1.000000            -0.110082
# Region_name_indexed        0.344365     -0.110082             1.000000

# %%
#Lets plot a graph and see how this looks like on graph

sb.heatmap(df_pearson, 
            xticklabels=df_spearman.columns,
            yticklabels=df_spearman.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.05)
# Out:
# <AxesSubplot:>

# %%
#calculate the correlation using the Kendall method
df_kendall = df.corr(method="kendall")
df_kendall
# Out:
#                      Unnamed: 0     Price  Distance   Zipcode  #Bedroom  \
# Unnamed: 0             1.000000  0.011271 -0.000093  0.000571  0.001988
# Price                  0.011271  1.000000 -0.205374  0.193832  0.325641
# Distance              -0.000093 -0.205374  1.000000  0.189624  0.201695
# Zipcode                0.000571  0.193832  0.189624  1.000000  0.061825
# #Bedroom               0.001988  0.325641  0.201695  0.061825  1.000000
# #Bathroom              0.011091  0.302298  0.092300  0.121199  0.527088
# #-Car Garage          -0.006646  0.149476  0.226561  0.054401  0.365610
# Lot_size              -0.001501  0.106699  0.219853  0.089649  0.267598
# Property_count         0.003424  0.023538 -0.076148  0.082197 -0.028625
# Suburb_indexed        -0.003347 -0.104373  0.243430  0.081055  0.067819
# Type_indexed          -0.005762 -0.281184 -0.057288  0.039658 -0.319186
# Region_name_indexed   -0.006504 -0.240627  0.256050 -0.333808  0.082693
#
#                      #Bathroom  #-Car Garage  Lot_size  Property_count  \
# Unnamed: 0            0.011091     -0.006646 -0.001501        0.003424
# Price                 0.302298      0.149476  0.106699        0.023538
# Distance              0.092300      0.226561  0.219853       -0.076148
# Zipcode               0.121199      0.054401  0.089649        0.082197
# #Bedroom              0.527088      0.365610  0.267598       -0.028625
# #Bathroom             1.000000      0.300084  0.106831       -0.014277
# #-Car Garage          0.300084      1.000000  0.268162       -0.014932
# Lot_size              0.106831      0.268162  1.000000       -0.016120
# Property_count       -0.014277     -0.014932 -0.016120        1.000000
# Suburb_indexed        0.057677      0.028178  0.077854       -0.471356
# Type_indexed         -0.047980     -0.162626 -0.202936        0.019687
# Region_name_indexed  -0.024646      0.053333  0.066086       -0.155918
#
#                      Suburb_indexed  Type_indexed  Region_name_indexed
# Unnamed: 0                -0.003347     -0.005762            -0.006504
# Price                     -0.104373     -0.281184            -0.240627
# Distance                   0.243430     -0.057288             0.256050
# Zipcode                    0.081055      0.039658            -0.333808
# #Bedroom                   0.067819     -0.319186             0.082693
# #Bathroom                  0.057677     -0.047980            -0.024646
# #-Car Garage               0.028178     -0.162626             0.053333
# Lot_size                   0.077854     -0.202936             0.066086
# Property_count            -0.471356      0.019687            -0.155918
# Suburb_indexed             1.000000     -0.037487             0.257802
# Type_indexed              -0.037487      1.000000            -0.097768
# Region_name_indexed        0.257802     -0.097768             1.000000

# %%
#Lets plot a graph and see how this looks like on graph

sb.heatmap(df_kendall, 
            xticklabels=df_kendall.columns,
            yticklabels=df_kendall.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
#we have plotted 3 different method of correllation.
#If the goal is to predict what features will affect the price of the house or apartment, we can see from the three
#correllation method that number of bedroom "#Bedroom" will greatly affect the pricing. Now lets calculate individually the
#correllation of price against all the features in the dataset

# %%
#using price as the the goal or prediction value, we add it to a seperate dataframe
price_df = df["Price"]

# %%
#calculate the correllation coefficient with the pearson method
df.corrwith(price_df,method="pearson",axis=0)
# Out:
# Unnamed: 0             0.011719
# Price                  1.000000
# Distance              -0.262172
# Zipcode                0.113908
# #Bedroom               0.403429
# #Bathroom              0.435309
# #-Car Garage           0.180552
# Lot_size               0.023218
# Property_count        -0.024929
# Suburb_indexed        -0.161425
# Type_indexed          -0.241443
# Region_name_indexed   -0.311913
# dtype: float64

# %%
#calculate the correllation coefficient with the spearman method
df.corrwith(price_df,method="spearman",axis=0)
# Out:
# Unnamed: 0             0.016994
# Price                  1.000000
# Distance              -0.303331
# Zipcode                0.290693
# #Bedroom               0.415919
# #Bathroom              0.377854
# #-Car Garage           0.195914
# Lot_size               0.153381
# Property_count         0.032981
# Suburb_indexed        -0.157416
# Type_indexed          -0.356370
# Region_name_indexed   -0.327458
# dtype: float64

# %%
#calculate the correllation coefficient with the kendall method
df.corrwith(price_df,method="kendall",axis=0)
# Out:
# Unnamed: 0             0.011271
# Price                  1.000000
# Distance              -0.205374
# Zipcode                0.193832
# #Bedroom               0.325641
# #Bathroom              0.302298
# #-Car Garage           0.149476
# Lot_size               0.106699
# Property_count         0.023538
# Suburb_indexed        -0.104373
# Type_indexed          -0.281184
# Region_name_indexed   -0.240627
# dtype: float64

# %%
## we can see that across all the three methods for correllation, bedroom and bathroom are the the sole reason why price
#of a particular housing will be expensive.

#However we can see that, the pearson correllation coefficient says otherwise. It says that the bathroom is responsible for
#increase in pricing unlike spearman and kendall method
